# %%
import os
import sklearn as skl
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
downloaded_file = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True
)

# %%
df = pd.read_csv(downloaded_file)

# %%
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %%
pd.

# %%
df.dtypes
# Out:
# Date Time           object
# p (mbar)           float64
# T (degC)           float64
# Tpot (K)           float64
# Tdew (degC)        float64
# rh (%)             float64
# VPmax (mbar)       float64
# VPact (mbar)       float64
# VPdef (mbar)       float64
# sh (g/kg)          float64
# H2OC (mmol/mol)    float64
# rho (g/m**3)       float64
# wv (m/s)           float64
# max. wv (m/s)      float64
# wd (deg)           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date Time', 'p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)',
#        'rh (%)', 'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'wv (m/s)', 'max. wv (m/s)',
#        'wd (deg)'],
#       dtype='object')

# %%
df[5::6]
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 5        94.40          3.33          3.14          0.19       1.96
# 11       93.20          3.12          2.90          0.21       1.81
# 17       93.50          3.13          2.93          0.20       1.83
# 23       92.60          3.07          2.85          0.23       1.78
# 29       92.20          2.94          2.71          0.23       1.69
# ...        ...           ...           ...           ...        ...
# 420521   72.00          5.69          4.09          1.59       2.54
# 420527   66.29          5.51          3.65          1.86       2.27
# 420533   72.90          4.99          3.64          1.35       2.26
# 420539   72.30          4.93          3.57          1.37       2.22
# 420545   72.60          4.56          3.31          1.25       2.06
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5                  3.15       1307.86      0.21           0.63     192.7
# 11                 2.91       1312.25      0.25           0.63     190.3
# 17                 2.94       1312.18      0.18           0.63     167.2
# 23                 2.85       1313.61      0.10           0.38     240.0
# 29                 2.71       1317.19      0.40           0.88     157.0
# ...                 ...           ...       ...            ...       ...
# 420521             4.08       1280.70      0.87           1.36     190.6
# 420527             3.65       1281.87      1.02           1.92     225.4
# 420533             3.63       1288.02      0.71           1.56     158.7
# 420539             3.57       1288.03      0.35           0.68     216.7
# 420545             3.31       1292.41      0.56           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')

# %%
df.head()
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 00:10:00  01.01.2009 00:10:00    996.52     -8.02    265.40
# 2009-01-01 00:20:00  01.01.2009 00:20:00    996.57     -8.41    265.01
# 2009-01-01 00:30:00  01.01.2009 00:30:00    996.53     -8.51    264.91
# 2009-01-01 00:40:00  01.01.2009 00:40:00    996.51     -8.31    265.12
# 2009-01-01 00:50:00  01.01.2009 00:50:00    996.51     -8.27    265.15
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# 2009-01-01 00:10:00        -8.90    93.3          3.33          3.11
# 2009-01-01 00:20:00        -9.28    93.4          3.23          3.02
# 2009-01-01 00:30:00        -9.31    93.9          3.21          3.01
# 2009-01-01 00:40:00        -9.07    94.2          3.26          3.07
# 2009-01-01 00:50:00        -9.04    94.1          3.27          3.08
#
#                      VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# Date Time
# 2009-01-01 00:10:00          0.22       1.94             3.12       1307.75
# 2009-01-01 00:20:00          0.21       1.89             3.03       1309.80
# 2009-01-01 00:30:00          0.20       1.88             3.02       1310.24
# 2009-01-01 00:40:00          0.19       1.92             3.08       1309.19
# 2009-01-01 00:50:00          0.19       1.92             3.09       1309.00
#
#                      wv (m/s)  max. wv (m/s)  wd (deg)
# Date Time
# 2009-01-01 00:10:00      1.03           1.75     152.3
# 2009-01-01 00:20:00      0.72           1.50     136.1
# 2009-01-01 00:30:00      0.19           0.63     171.6
# 2009-01-01 00:40:00      0.34           0.50     198.0
# 2009-01-01 00:50:00      0.32           0.63     214.3

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <AxesSubplot:xlabel='Date Time'>

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        
        row = [[a] for a in df_as_np[i:i+window_size]]
        X.append(row)

        label = df_as_np[i+window_size]
        y.append(label)

        return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(temp, WINDOW_SIZE)

# %%
X.shape, y.shape
# Out:
# ((1, 5, 1), (1,))

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
X
# Out:
# array([[[-8.02],
#         [-8.41],
#         [-8.51],
#         [-8.31],
#         [-8.27]]])

# %%
# !pip install "jupyter-kite<2.0.0"
# Out:
# Collecting jupyter-kite<2.0.0
#   Downloading jupyter-kite-1.2.0.tar.gz (30 kB)
# Requirement already satisfied: notebook>=4.3.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-kite<2.0.0) (6.4.5)
# Requirement already satisfied: tornado>=5.1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-kite<2.0.0) (6.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jupyter-kite<2.0.0) (58.0.4)
# Requirement already satisfied: traitlets>=4.2.1 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (5.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (4.8.1)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (20.1.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (6.1.12)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (6.1.0)
# Requirement already satisfied: ipykernel in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (6.4.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (0.11.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (2.11.3)
# Requirement already satisfied: nbformat in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (5.1.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (1.8.0)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.3.1->jupyter-kite<2.0.0) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.3.1->jupyter-kite<2.0.0) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.3.1->jupyter-kite<2.0.0) (228)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=5.3.4->notebook>=4.3.1->jupyter-kite<2.0.0) (1.16.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\programdata\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.3.1->jupyter-kite<2.0.0) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.3.1->jupyter-kite<2.0.0) (1.14.6)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.3.1->jupyter-kite<2.0.0) (2.20)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (1.4.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (7.29.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.18.0)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (3.0.20)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.2.0)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (2.10.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.8.2)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook>=4.3.1->jupyter-kite<2.0.0) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->notebook>=4.3.1->jupyter-kite<2.0.0) (1.1.1)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (4.0.0)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.3)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.1.2)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.7.1)
# Requirement already satisfied: async-generator in c:\programdata\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (1.10)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (1.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\programdata\anaconda3\lib\site-packages (from nbformat->notebook>=4.3.1->jupyter-kite<2.0.0) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.3.1->jupyter-kite<2.0.0) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.3.1->jupyter-kite<2.0.0) (0.18.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (0.5.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.3.1->jupyter-kite<2.0.0) (3.0.4)
# Building wheels for collected packages: jupyter-kite
#   Building wheel for jupyter-kite (setup.py): started
#   Building wheel for jupyter-kite (setup.py): finished with status 'done'
#   Created wheel for jupyter-kite: filename=jupyter_kite-1.2.0-py3-none-any.whl size=43040 sha256=4a4ba52831ec66b2eb09a46feae6de8768c9794e91ee8271ba1757b0b8c85632
#   Stored in directory: c:\users\srush\appdata\local\pip\cache\wheels\73\b9\72\0e59ef864a69d5d7d21f931cd8674bfd5d5b74b7b15eef4c58
# Successfully built jupyter-kite
# Installing collected packages: jupyter-kite
# Successfully installed jupyter-kite-1.2.0
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)

# %%
# !jupyter labextension install "@kiteco/jupyterlab-kite"
# Out:
# ^C
# Building jupyterlab assets (production, minimized)
# An error occurred.
# RuntimeError: npm dependencies failed to install
# See the log file for details:  C:\Users\Srush\AppData\Local\Temp\jupyterlab-debug-l_trjn_5.log

# %%
import pandas as pd
